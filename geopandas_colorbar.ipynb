# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
# %matplotlib inline
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

cmap = mpl.cm.viridis_r
norm = mpl.colors.Normalize(vmin=0, vmax=1.25e9)

gs_kw = dict(width_ratios=[20,1], height_ratios=[1])
fig, (ax1, ax2) = plt.subplots(ncols=2, gridspec_kw=gs_kw)
world.plot(column='pop_est', cmap=cmap, norm=norm, ax=ax1)
mpl.colorbar.ColorbarBase(ax2, cmap=cmap, norm=norm)
ax1.set_aspect('equal')
